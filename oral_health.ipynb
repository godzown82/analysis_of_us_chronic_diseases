# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt

from cdindicatorFn import check_year_columns, group_sort, question_us_overall, datavalue_type_filter, plot_graph_dict_neutral, change_plot_color

# %%
#reads in the csv file
oral_health_df = pd.read_csv('Oral Health.csv', low_memory=False)

# %%
#checks to see if columns YearEnd and YearStart have the same value: prints statement and creates new column YearDiffernce if necessary
oral_health_df = check_year_columns(oral_health_df)
# Out:
# The 'YearStart' and 'YearEnd' columns do not have the same values in all rows.

# %%
#groups data frames by YearEnd and Question, then sorts the data frame by YearENd least to greatest
oral_health_df = group_sort(oral_health_df)

# %%
oral_health_df['Question'].value_counts()
# Out:
# Question
# Visits to dentist or dental clinic among adults aged >= 18 years                        3959
# No tooth loss among adults aged 18-64 years                                             3890
# Six or more teeth lost among adults aged >= 65 years                                    2905
# All teeth lost among adults aged >= 65 years                                            2586
# Preventive dental care before pregnancy                                                 1600
# Dental visits among children and adolescents aged 1-17 years                             624
# Preventive dental visits among children and adolescents aged 1-17 years                  624
# Oral health services at Federally Qualified Health Centers                               549
# Population served by community water systems that receive fluoridated drinking water     208
# Name: count, dtype: int64

# %%
#creates a dictionary of dataframes that are seperated by question and filtered to US and overall stratification category
# Does not include dataframes that don't include data that can be filtered to US and/or overall
oral_health_us_overall = question_us_overall(oral_health_df)

# %%
# filters each dataframe in the dictionary to the desired Datavalue type
oral_health_us_overall = datavalue_type_filter(oral_health_us_overall)

# %%
#plots each data frame in the dictionary separatley and colors them red, then stores them in a new dictionary graphs
oral_health_graphs = plot_graph_dict_neutral(oral_health_us_overall)

# %% [markdown]
# # <center>DATA EXPLORATION<center>
