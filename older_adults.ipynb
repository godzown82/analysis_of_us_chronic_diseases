# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt

from cdindicatorFn import check_year_columns, group_sort, question_us_overall, datavalue_type_filter, plot_graph_dict_neutral, change_plot_color

# %%
#reads in the csv file
older_adults_df = pd.read_csv('Older Adults.csv', low_memory=False)

# %%
#checks to see if columns YearEnd and YearStart have the same value: prints statement and creates new column YearDiffernce if necessary
older_adults_df = check_year_columns(older_adults_df)
# Out:
# The 'YearStart' and 'YearEnd' columns have the same values in all rows.

# %%
#groups data frames by YearEnd and Question, then sorts the data frame by YearENd least to greatest
older_adults_df = group_sort(older_adults_df)

# %%
older_adults_df['Question'].value_counts()
# Out:
# Question
# Hospitalization for hip fracture among Medicare-eligible persons aged >= 65 years                               9792
# Prevalence of 2 or more chronic conditions among Medicare-enrolled persons aged >= 65 years                     3649
# Proportion of older adults aged 50-64 years who are up to date on a core set of clinical preventive services    2916
# Proportion of older adults aged >= 65 years who are up to date on a core set of clinical preventive services    2894
# Name: count, dtype: int64

# %%
#creates a dictionary of dataframes that are seperated by question and filtered to US and overall stratification category
# Does not include dataframes that don't include data that can be filtered to US and/or overall
older_adults_us_overall = question_us_overall(older_adults_df)

# %%
# filters each dataframe in the dictionary to the desired Datavalue type
older_adults_us_overall = datavalue_type_filter(older_adults_us_overall)

# %%
#plots each data frame in the dictionary separatley and colors them red, then stores them in a new dictionary graphs
older_adults_graphs = plot_graph_dict_neutral(older_adults_us_overall)

# %% [markdown]
# # <center>DATA EXPLORATION<center>
