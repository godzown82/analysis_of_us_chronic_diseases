# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt

# %%
cardiovascular_disease_df = pd.read_csv('Cardiovascular Disease.csv')
# Out:
# C:\Users\Brian Willery\AppData\Local\Temp\ipykernel_15400\3861845633.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   cardiovascular_disease_df = pd.read_csv('Cardiovascular Disease.csv')

# %%
cardiovascular_disease_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'Topic', 'Question',
#        'DataValue', 'DataValueUnit', 'DataValueType', 'DatavalueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1'],
#       dtype='object')

# %%
cardiovascular_disease_df['DataValueUnit'].value_counts()
# Out:
# DataValueUnit
# %                    38626
# cases per 100,000    37279
# cases per 1,000       7490
# cases per 10,000      4926
# Number                3144
# Name: count, dtype: int64

# %%
cardiovascular_disease_df['Question'].value_counts()
# Out:
# Question
# Mortality from total cardiovascular diseases                                                                                   12036
# Mortality from diseases of the heart                                                                                           11703
# Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years                                             11235
# Mortality from coronary heart disease                                                                                          11046
# Mortality from heart failure                                                                                                   10902
# Mortality from cerebrovascular disease (stroke)                                                                                10230
# Influenza vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease or stroke     5082
# Influenza vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease or stroke     4939
# Cholesterol screening among adults aged >= 18 years                                                                             4872
# Awareness of high blood pressure among adults aged >= 18 years                                                                  4845
# High cholesterol prevalence among adults aged >= 18 years                                                                       4765
# Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease            4762
# Taking medicine for high blood pressure control among adults aged >= 18 years with high blood pressure                          4171
# Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease            4149
# Hospitalization for stroke                                                                                                      3738
# Hospitalization for acute myocardial infarction                                                                                 3651
# Awareness of high blood pressure among women aged 18-44 years                                                                   1032
# Pre-pregnancy hypertension                                                                                                         9
# Name: count, dtype: int64

# %%
cardiovascular_disease_df['LocationAbbr'].value_counts()
# Out:
# LocationAbbr
# NC    2708
# MI    2685
# WA    2680
# AZ    2675
# CO    2588
# OR    2583
# FL    2568
# WI    2563
# NY    2543
# MD    2517
# NV    2502
# NM    2472
# MN    2459
# CA    2419
# NJ    2416
# TX    2397
# SC    2352
# GA    2338
# OK    2332
# MA    2288
# KS    2253
# AR    2248
# KY    2247
# VA    2234
# IA    2209
# OH    2193
# MO    2180
# HI    2174
# LA    2165
# PA    2148
# RI    2143
# IN    2140
# UT    2105
# CT    2099
# IL    2093
# NE    2087
# MS    2059
# AL    2041
# TN    2037
# DC    1891
# AK    1888
# WV    1886
# SD    1864
# DE    1826
# ID    1705
# MT    1675
# VT    1582
# ND    1579
# WY    1551
# ME    1547
# NH    1466
# US     841
# PR     538
# GU     388
# Name: count, dtype: int64

# %%
#This code will show me if the YearStart column and the YearEnd column are all the same or not
same_years = (cardiovascular_disease_df['YearStart'] == cardiovascular_disease_df['YearEnd']).all()

if same_years:
    print("The 'YearStart' and 'YearEnd' columns have the same values in all rows.")
else:
    print("The 'YearStart' and 'YearEnd' columns do not have the same values in all rows.")
# Out:
# The 'YearStart' and 'YearEnd' columns have the same values in all rows.

# %%
#need to put the YearStart in order
cardiovascular_disease_df=cardiovascular_disease_df.sort_values(by='YearEnd')
cardiovascular_disease_df
# Out:
#         YearStart  YearEnd LocationAbbr                   Topic  \
# 27806        2010     2010           NJ  Cardiovascular Disease
# 30293        2010     2010           AR  Cardiovascular Disease
# 56964        2010     2010           US  Cardiovascular Disease
# 30306        2010     2010           SD  Cardiovascular Disease
# 30309        2010     2010           MS  Cardiovascular Disease
# ...           ...      ...          ...                     ...
# 87780        2021     2021           KY  Cardiovascular Disease
# 106851       2021     2021           TX  Cardiovascular Disease
# 106850       2021     2021           TX  Cardiovascular Disease
# 87698        2021     2021           KY  Cardiovascular Disease
# 107665       2021     2021           UT  Cardiovascular Disease
#
#                                                  Question  DataValue  \
# 27806                Mortality from diseases of the heart     176.50
# 30293               Mortality from coronary heart disease     186.50
# 56964   Hospitalization for heart failure among Medica...      19.56
# 30306                Mortality from diseases of the heart     151.70
# 30309               Mortality from coronary heart disease     162.50
# ...                                                   ...        ...
# 87780   Taking medicine for high blood pressure contro...      67.90
# 106851  Cholesterol screening among adults aged >= 18 ...      85.70
# 106850  Influenza vaccination among noninstitutionaliz...      28.10
# 87698   Awareness of high blood pressure among women a...      20.90
# 107665  Cholesterol screening among adults aged >= 18 ...      85.20
#
#             DataValueUnit            DataValueType DatavalueFootnote  \
# 27806   cases per 100,000               Crude Rate               NaN
# 30293   cases per 100,000               Crude Rate               NaN
# 56964     cases per 1,000               Crude Rate               NaN
# 30306   cases per 100,000        Age-adjusted Rate               NaN
# 30309   cases per 100,000        Age-adjusted Rate               NaN
# ...                   ...                      ...               ...
# 87780                   %  Age-adjusted Prevalence               NaN
# 106851                  %         Crude Prevalence               NaN
# 106850                  %  Age-adjusted Prevalence               NaN
# 87698                   %         Crude Prevalence               NaN
# 107665                  %         Crude Prevalence               NaN
#
#         LowConfidenceLimit  HighConfidenceLimit StratificationCategory1  \
# 27806               168.90               184.10          Race/Ethnicity
# 30293               180.80               192.20          Race/Ethnicity
# 56964                18.78                20.33          Race/Ethnicity
# 30306               144.00               159.50          Race/Ethnicity
# 30309               155.30               169.80                  Gender
# ...                    ...                  ...                     ...
# 87780                63.30                72.20                  Gender
# 106851               74.30                92.50          Race/Ethnicity
# 106850               19.50                38.80                 Overall
# 87698                17.30                25.00          Race/Ethnicity
# 107665               82.30                87.70          Race/Ethnicity
#
#                          Stratification1
# 27806                Black, non-Hispanic
# 30293                White, non-Hispanic
# 56964   American Indian or Alaska Native
# 30306                White, non-Hispanic
# 30309                               Male
# ...                                  ...
# 87780                               Male
# 106851         Multiracial, non-Hispanic
# 106850                           Overall
# 87698                White, non-Hispanic
# 107665                          Hispanic
#
# [113167 rows x 13 columns]

# %%
#This would turn 'YearEnd' into a date time by year but im sure why would need to do this will investigate more
#cardiovascular_disease_df['YearEnd'] = pd.to_datetime(cardiovascular_disease_df['YearEnd'], format='%Y')

#This code allows us to display value counts in order by year so we can see the order of years and how many rows of data each year contains
# use this code if you convert to datetime (year_end_counts = cardiovascular_disease_df['YearEnd'].dt.year.value_counts().sort_index())
year_end_counts = cardiovascular_disease_df['YearEnd'].value_counts().sort_index()
year_end_counts
#data summary for years: it looks like 2007 could be considered an outlier and possibly unusable for our analysis
# Out:
# YearEnd
# 2010     7041
# 2011    11114
# 2012     7815
# 2013    12010
# 2014     9007
# 2015    12137
# 2016     8983
# 2017    12244
# 2018     9053
# 2019    11067
# 2020     7890
# 2021     4806
# Name: count, dtype: int64

# %%
# chekcing the dtype of the column 'YearEnd', thus far int64 is our goal, but might check again if datetime becomes our targeted dtype
cardiovascular_disease_df['YearEnd'].dtype
# Out:
# dtype('int64')

# %%
#need to explore what kind of data we have in the DataValue comlumn to see what we can compare and use for a graph
#footnotes should give me an idea of what the numbers mean, check against documentation for further understanding
#need to understand if the questions datavalue is infering more or lesslikley hood of chronic desease
#Questions could be something that we could compare, need to check if the datavalues are comparable for all the same Questions
#what will groupby do if i groupby question: desired result it will group all same questions together to have comparable data amongst the same questions
#I might also need to groupby year: desired result all the same question whithin a particular year grouped together so I can show yearly changes with comparable data
#The LocationAbbr includes US, which has to be addressed
#we need to seperate or group by year,question, stratificationCategory1 and then stratification1 if not Overall


cardiovascular_disease_df
# Out:
#         YearStart  YearEnd LocationAbbr                   Topic  \
# 27806        2010     2010           NJ  Cardiovascular Disease
# 30293        2010     2010           AR  Cardiovascular Disease
# 56964        2010     2010           US  Cardiovascular Disease
# 30306        2010     2010           SD  Cardiovascular Disease
# 30309        2010     2010           MS  Cardiovascular Disease
# ...           ...      ...          ...                     ...
# 87780        2021     2021           KY  Cardiovascular Disease
# 106851       2021     2021           TX  Cardiovascular Disease
# 106850       2021     2021           TX  Cardiovascular Disease
# 87698        2021     2021           KY  Cardiovascular Disease
# 107665       2021     2021           UT  Cardiovascular Disease
#
#                                                  Question  DataValue  \
# 27806                Mortality from diseases of the heart     176.50
# 30293               Mortality from coronary heart disease     186.50
# 56964   Hospitalization for heart failure among Medica...      19.56
# 30306                Mortality from diseases of the heart     151.70
# 30309               Mortality from coronary heart disease     162.50
# ...                                                   ...        ...
# 87780   Taking medicine for high blood pressure contro...      67.90
# 106851  Cholesterol screening among adults aged >= 18 ...      85.70
# 106850  Influenza vaccination among noninstitutionaliz...      28.10
# 87698   Awareness of high blood pressure among women a...      20.90
# 107665  Cholesterol screening among adults aged >= 18 ...      85.20
#
#             DataValueUnit            DataValueType DatavalueFootnote  \
# 27806   cases per 100,000               Crude Rate               NaN
# 30293   cases per 100,000               Crude Rate               NaN
# 56964     cases per 1,000               Crude Rate               NaN
# 30306   cases per 100,000        Age-adjusted Rate               NaN
# 30309   cases per 100,000        Age-adjusted Rate               NaN
# ...                   ...                      ...               ...
# 87780                   %  Age-adjusted Prevalence               NaN
# 106851                  %         Crude Prevalence               NaN
# 106850                  %  Age-adjusted Prevalence               NaN
# 87698                   %         Crude Prevalence               NaN
# 107665                  %         Crude Prevalence               NaN
#
#         LowConfidenceLimit  HighConfidenceLimit StratificationCategory1  \
# 27806               168.90               184.10          Race/Ethnicity
# 30293               180.80               192.20          Race/Ethnicity
# 56964                18.78                20.33          Race/Ethnicity
# 30306               144.00               159.50          Race/Ethnicity
# 30309               155.30               169.80                  Gender
# ...                    ...                  ...                     ...
# 87780                63.30                72.20                  Gender
# 106851               74.30                92.50          Race/Ethnicity
# 106850               19.50                38.80                 Overall
# 87698                17.30                25.00          Race/Ethnicity
# 107665               82.30                87.70          Race/Ethnicity
#
#                          Stratification1
# 27806                Black, non-Hispanic
# 30293                White, non-Hispanic
# 56964   American Indian or Alaska Native
# 30306                White, non-Hispanic
# 30309                               Male
# ...                                  ...
# 87780                               Male
# 106851         Multiracial, non-Hispanic
# 106850                           Overall
# 87698                White, non-Hispanic
# 107665                          Hispanic
#
# [113167 rows x 13 columns]

# %%
smokless_df =cardiovascular_disease_df.loc[cardiovascular_disease_df['Question'] == 'Current smokeless cardiovascular_disease use among adults aged >= 18 years']
smokless_df
# Out:
# Empty DataFrame
# Columns: [YearStart, YearEnd, LocationAbbr, Topic, Question, DataValue, DataValueUnit, DataValueType, DatavalueFootnote, LowConfidenceLimit, HighConfidenceLimit, StratificationCategory1, Stratification1]
# Index: []

# %%
#This groups the dataframe first by Year and then question, StratificationCat1, stratification, and finally groups by location
#It then applys a lambda function to make sure the years are in order.
#This currently does not address US in the locations with individual states
grouped_cardiovascular_disease_df = cardiovascular_disease_df.groupby(['YearEnd','Question','StratificationCategory1','Stratification1','LocationAbbr']).apply(
    lambda x: x.sort_values(by = 'YearEnd')).reset_index(drop = True)

grouped_cardiovascular_disease_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr                   Topic  \
# 0       2010     2010           AR  Cardiovascular Disease
# 1       2010     2010           AR  Cardiovascular Disease
# 2       2010     2010           AR  Cardiovascular Disease
# 3       2010     2010           AZ  Cardiovascular Disease
# 4       2010     2010           AZ  Cardiovascular Disease
#
#                                           Question  DataValue  \
# 0  Hospitalization for acute myocardial infarction      20.45
# 1  Hospitalization for acute myocardial infarction      13.28
# 2  Hospitalization for acute myocardial infarction    2450.00
# 3  Hospitalization for acute myocardial infarction    3836.00
# 4  Hospitalization for acute myocardial infarction      14.98
#
#       DataValueUnit      DataValueType DatavalueFootnote  LowConfidenceLimit  \
# 0  cases per 10,000         Crude Rate               NaN               19.64
# 1  cases per 10,000  Age-adjusted Rate               NaN               12.75
# 2               NaN             Number               NaN                 NaN
# 3               NaN             Number               NaN                 NaN
# 4  cases per 10,000         Crude Rate               NaN               14.51
#
#    HighConfidenceLimit StratificationCategory1 Stratification1
# 0                21.26                  Gender          Female
# 1                13.80                  Gender          Female
# 2                  NaN                  Gender          Female
# 3                  NaN                  Gender          Female
# 4                15.45                  Gender          Female

# %%
#use this to look at a list of possible questions to choose from
grouped_cardiovascular_disease_df['Question'].value_counts()
# Out:
# Question
# Mortality from total cardiovascular diseases                                                                                   12036
# Mortality from diseases of the heart                                                                                           11703
# Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years                                             11235
# Mortality from coronary heart disease                                                                                          11046
# Mortality from heart failure                                                                                                   10902
# Mortality from cerebrovascular disease (stroke)                                                                                10230
# Influenza vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease or stroke     5082
# Influenza vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease or stroke     4939
# Cholesterol screening among adults aged >= 18 years                                                                             4872
# Awareness of high blood pressure among adults aged >= 18 years                                                                  4845
# High cholesterol prevalence among adults aged >= 18 years                                                                       4765
# Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease            4762
# Taking medicine for high blood pressure control among adults aged >= 18 years with high blood pressure                          4171
# Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease            4149
# Hospitalization for stroke                                                                                                      3738
# Hospitalization for acute myocardial infarction                                                                                 3651
# Awareness of high blood pressure among women aged 18-44 years                                                                   1032
# Pre-pregnancy hypertension                                                                                                         9
# Name: count, dtype: int64

# %%
#The question is can we turn this into a function to apply to other csvs???

#creates a list with all the target valus in the Questions column
questions = grouped_cardiovascular_disease_df['Question'].unique().tolist()
#creating an empty dictionary to store dataframes with their own unique questions
dfs = {}
#looping through our grouped dataframe to create multiple dataframes containing only one question along with its values and then storing them in a dictionary
# also sets their key values to the target question in their respective dataframes
for question in questions:
    df_name = question
    dfs[df_name] = grouped_cardiovascular_disease_df.loc[grouped_cardiovascular_disease_df['Question'] == question]\
        .loc[grouped_cardiovascular_disease_df['LocationAbbr'] == 'US']\
        .loc[grouped_cardiovascular_disease_df['StratificationCategory1'] == 'Overall']

# %%
#loops through the dfs dictionary to extract the individual dfs by their 'Question' name and then plot them by yearend and datavalue
for df_name, df in dfs.items():
    plt.figure(figsize=(10, 6))
    plt.plot(df['YearEnd'], df['DataValue'], label=df['DataValueUnit'].count())
    plt.xlabel('YearEnd')
    plt.ylabel('DataValue')
    title = df_name.replace('_', ' ').title()
    plt.title(title)
    plt.legend()
    # plt.savefig(f'{title}.png')
    plt.show()

# %% [markdown]
# Results: 'Percent tobacco revenue to fund at CDC recommended level' & 'Sale of cigarette packs' & 'Secondary schools that have a comprehensive tobacco-free school policy in place' dataframes don't have US or possibly Overall data causing them to be empty
#
# dataframes with similar datavalue units that we could possibly plot on one graph:
#     us_overall_ciggarette_women_age18_44_df=dfs['Current cigarette smoking among women aged 18-44 years']
#     us_overall_smokingb4pregnancy_df = dfs['Cigarette smoking before pregnancy']
# #The top two have ranges 14 to 22 and the bottom has 15 to 21 could possibly combine these
#     us_overall_18_older_smokers_df = dfs['Current smoking among adults aged >= 18 years']
#
# #range 4 to 9
#     us_overall_smokeless_youth_df=dfs['Current smokeless tobacco use among youth']
# #range 6 to 16
#     us_overall_cigarette_youth_df=dfs['Current cigarette smoking among youth']
#
# #range 52 to 66
#     us_overall_quit_tobacco_df = dfs['Quit attempts in the past year among current smokers']
# #range 60 to 68
#     us_overall_pneumococcal_vaccination_adult_age65_older_smokers_df=dfs['Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years who smoke']
# #range 50 to 62
#     us_overall_smoke_free_indoor_policy=dfs['Proportion of the population protected by a comprehensive smoke-free policy prohibiting smoking in all indoor areas of workplaces and public places, including restaurants and bars']

# %%
#renaming all the dataframes in the dfs{} and storing them in their respective dataframes
us_overall_18_older_smokers_df = dfs['Current smoking among adults aged >= 18 years']
us_overall_quit_cardiovascular_disease_df = dfs['Quit attempts in the past year among current smokers']
us_overall_pneumococcal_vaccination_adult_age18_64_smokers_df =dfs['Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years who smoke']
us_overall_smokeless_cardiovascular_disease_adult_df = dfs['Current smokeless cardiovascular_disease use among adults aged >= 18 years']
us_overall_pneumococcal_vaccination_adult_age65_older_smokers_df=dfs['Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years who smoke']
us_overall_ciggarette_women_age18_44_df=dfs['Current cigarette smoking among women aged 18-44 years']
us_overall_smokingb4pregnancy_df = dfs['Cigarette smoking before pregnancy']
us_overall_cigarette_youth_df=dfs['Current cigarette smoking among youth']
us_overall_smokeless_youth_df=dfs['Current smokeless cardiovascular_disease use among youth']
us_overall_smoke_free_indoor_policy=dfs['Proportion of the population protected by a comprehensive smoke-free policy prohibiting smoking in all indoor areas of workplaces and public places, including restaurants and bars']
us_overall_sale_cigarette_packs=dfs['Sale of cigarette packs']
us_overall_2nd_school_cardiovascular_disease_free_policy=dfs['Secondary schools that have a comprehensive cardiovascular_disease-free school policy in place']
us_overall_cardiovascular_disease_revenue_fund_cdc_level = dfs['Percent cardiovascular_disease revenue to fund at CDC recommended level']

# %%
#filter these by location and possibly Overall and maybe we could make a bar graph?
overall_sale_cigarette_packs_df=grouped_cardiovascular_disease_df.loc[grouped_cardiovascular_disease_df['Question'] == 'Sale of cigarette packs']\
.loc[grouped_cardiovascular_disease_df['StratificationCategory1'] == 'Overall']

overall_2nd_school_cardiovascular_disease_free_policy_df = grouped_cardiovascular_disease_df.loc[grouped_cardiovascular_disease_df['Question'] == 'Secondary schools that have a comprehensive cardiovascular_disease-free school policy in place']\
.loc[grouped_cardiovascular_disease_df['StratificationCategory1'] == 'Overall']

overall_cardiovascular_disease_revenue_fund_cdc_level_df =grouped_cardiovascular_disease_df.loc[grouped_cardiovascular_disease_df['Question'] == 'Percent cardiovascular_disease revenue to fund at CDC recommended level']\
.loc[grouped_cardiovascular_disease_df['StratificationCategory1'] == 'Overall'] 

#overall_sale_cigarette_packs_df
#overall_2nd_school_cardiovascular_disease_free_policy_df
#overall_cardiovascular_disease_revenue_fund_cdc_level_df

overall_sale_cigarette_packs_df.plot(kind ='bar', x = 'YearEnd', y = "DataValue", label = 'Sale of Cigarette Packs')
overall_2nd_school_cardiovascular_disease_free_policy_df.plot(kind ='bar',x = 'YearEnd', y = "DataValue", label = 'Secondary schools that have a comprehensive cardiovascular_disease-free school policy in place')
overall_cardiovascular_disease_revenue_fund_cdc_level_df.plot(kind ='bar', x = 'YearEnd', y = "DataValue", label = 'Percent cardiovascular_disease revenue to fund at CDC recommended level')
#plt.legend()
#plt.figure(figsize=(20,10))
# Out:
# <Axes: xlabel='YearEnd'>

# %%
#lets choose a question with an easy to understand and compareble data value with the location being the US and the stratification being overall
# ill start by looking at questions and datavaluess
us_overall_smokingb4pregnancy_df =grouped_cardiovascular_disease_df.loc[grouped_cardiovascular_disease_df['Question'] == 'Cigarette smoking before pregnancy'].loc[grouped_cardiovascular_disease_df['LocationAbbr'] == 'US']\
.loc[grouped_cardiovascular_disease_df['StratificationCategory1'] == 'Overall']

us_overall_quit_cardiovascular_disease_df =grouped_cardiovascular_disease_df.loc[grouped_cardiovascular_disease_df['Question'] == 'Quit attempts in the past year among current smokers'].loc[grouped_cardiovascular_disease_df['LocationAbbr'] == 'US']\
.loc[grouped_cardiovascular_disease_df['StratificationCategory1'] == 'Overall']
#us_overall_smokingb4pregnancy_df
#us_overall_quit_cardiovascular_disease_df.info()
#us_overall_quit_cardiovascular_disease_df[['DataValue', 'DataValueUnit', 'DataValueType']]

# %%
us_overall_smokingb4pregnancy_df.plot(x = 'YearEnd', y = "DataValue", label = 'Smoking before pregancy')
us_overall_quit_cardiovascular_disease_df.plot(x = 'YearEnd', y = "DataValue", label = 'Attempts to quit cardiovascular_disease')
plt.legend()

# plt.plot(us_overall_quit_cardiovascular_disease_df['YearEnd'], us_overall_quit_cardiovascular_disease_df['DataValue'], label = "Attempts to quit cardiovascular_disease")
# plt.plot(us_overall_smokingb4pregnancy_df["YearEnd"], us_overall_smokingb4pregnancy_df['DataValue'], label = 'Smoking before pregancy')
# plt.legend()


# plt.plot( question_year_filter["YearEnd"] , question_year_filter['Question1'], label = 'Change1')
# plt.plot( question_year_filter["YearEnd"] , question_year_filter['Question2'], label = 'Question2')
# plt.xlabel('Year')
# plt.ylabel('Question')
# plt.title('cardiovascular_disease')
# plt.legend()

# %%
plt.plot(us_overall_quit_cardiovascular_disease_df['YearEnd'], us_overall_quit_cardiovascular_disease_df['DataValue'], label = "Attempts to quit cardiovascular_disease")
plt.plot(us_overall_smokingb4pregnancy_df["YearEnd"], us_overall_smokingb4pregnancy_df['DataValue'], label = 'Smoking before pregancy')
plt.legend()


# plt.plot( question_year_filter["YearEnd"] , question_year_filter['Question1'], label = 'Change1')
# plt.plot( question_year_filter["YearEnd"] , question_year_filter['Question2'], label = 'Question2')
# plt.xlabel('Year')
# plt.ylabel('Question')
# plt.title('cardiovascular_disease')
# plt.legend()

# %%
cardiovascular_disease_df['Question'].value_counts()
# Out:
# Question
# Current smoking among adults aged >= 18 years                                                                                                                                          8645
# Quit attempts in the past year among current smokers                                                                                                                                   6293
# Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years who smoke                                                                                                  5852
# Current smokeless tobacco use among adults aged >= 18 years                                                                                                                            5384
# Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years who smoke                                                                                                  4497
# Current cigarette smoking among women aged 18-44 years                                                                                                                                 1894
# Cigarette smoking before pregnancy                                                                                                                                                     1602
# Current cigarette smoking among youth                                                                                                                                                  1041
# Current smokeless tobacco use among youth                                                                                                                                               546
# Proportion of the population protected by a comprehensive smoke-free policy prohibiting smoking in all indoor areas of workplaces and public places, including restaurants and bars     322
# Sale of cigarette packs                                                                                                                                                                 306
# Secondary schools that have a comprehensive tobacco-free school policy in place                                                                                                         186
# Percent tobacco revenue to fund at CDC recommended level                                                                                                                                102
# Name: count, dtype: int64

# %%
#we first filtered the dataframe to only include 2 questions as well as location = US, stratification = Overall

question_year_df =grouped_cardiovascular_disease_df.loc[grouped_cardiovascular_disease_df['Question'].isin(['Current smoking among adults aged >= 18 years', 'Current smokeless cardiovascular_disease use among adults aged >= 18 years'])].loc[grouped_cardiovascular_disease_df['LocationAbbr'] == 'US']\
.loc[grouped_cardiovascular_disease_df['StratificationCategory1'] == 'Overall']

#put each question into its own list
# Create new columns based on the values in the 'Initial_Column'
question_year_df['Question1'] = np.where(question_year_df['Question'] =='Current smoking among adults aged >= 18 years',
                                         question_year_df['DataValue'],
                                         np.nan)
question_year_df['Question2'] = np.where(question_year_df['Question'] =='Current smokeless cardiovascular_disease use among adults aged >= 18 years',
                                         question_year_df['DataValue'],
                                         np.nan)
question_year_df.head()
# Out:
#       YearStart  YearEnd LocationAbbr    Topic  \
# 594        2011     2011           US  Tobacco
# 595        2011     2011           US  Tobacco
# 1115       2011     2011           US  Tobacco
# 1116       2011     2011           US  Tobacco
# 3808       2012     2012           US  Tobacco
#
#                                                Question  DataValue  \
# 594   Current smokeless tobacco use among adults age...        4.4
# 595   Current smokeless tobacco use among adults age...        4.5
# 1115      Current smoking among adults aged >= 18 years       21.2
# 1116      Current smoking among adults aged >= 18 years       21.3
# 3808  Current smokeless tobacco use among adults age...        4.1
#
#      DataValueUnit            DataValueType          DatavalueFootnote  \
# 594              %         Crude Prevalence  50 States + DC: US Median
# 595              %  Age-adjusted Prevalence  50 States + DC: US Median
# 1115             %         Crude Prevalence  50 States + DC: US Median
# 1116             %  Age-adjusted Prevalence  50 States + DC: US Median
# 3808             %  Age-adjusted Prevalence  50 States + DC: US Median
#
#       LowConfidenceLimit  HighConfidenceLimit StratificationCategory1  \
# 594                  3.6                  4.8                 Overall
# 595                  3.7                  5.0                 Overall
# 1115                20.0                 22.4                 Overall
# 1116                20.3                 22.5                 Overall
# 3808                 3.9                  4.7                 Overall
#
#      Stratification1  Question1  Question2
# 594          Overall        NaN        4.4
# 595          Overall        NaN        4.5
# 1115         Overall       21.2        NaN
# 1116         Overall       21.3        NaN
# 3808         Overall        NaN        4.1

# %%
question_year_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'Topic', 'Question',
#        'DataValue', 'DataValueUnit', 'DataValueType', 'DatavalueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'Question1', 'Question2'],
#       dtype='object')

# %%
question_year_filter = question_year_df[['YearEnd','Question1','Question2']]
#question_year_filter.set_index("YearEnd")
question_year_filter.head()
# Out:
#       YearEnd  Question1  Question2
# 594      2011        NaN        4.4
# 595      2011        NaN        4.5
# 1115     2011       21.2        NaN
# 1116     2011       21.3        NaN
# 3808     2012        NaN        4.1

# %%
#ploting 2 question on the same graph with YearEnd as the x axis
plt.plot( question_year_filter["YearEnd"] , question_year_filter['Question1'], label = 'Change1')
plt.plot( question_year_filter["YearEnd"] , question_year_filter['Question2'], label = 'Question2')
plt.xlabel('Year')
plt.ylabel('Question')
plt.title('cardiovascular_disease')
plt.legend()

# %%
#df['column_name'] = df['column_name'].astype(int)
question_year_filter['YearEnd'] = question_year_filter['YearEnd'].astype(int)

question_year_filter[['Question1', 'Question2']].plot()



#question_year_filter.plot(y = 'Question1', 'Question2')
# Out:
# C:\Users\tyzwh\AppData\Local\Temp\ipykernel_32328\2962594156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   question_year_filter['YearEnd'] = question_year_filter['YearEnd'].astype(int)
# <Axes: >

# %%
us_overall_df =grouped_cardiovascular_disease_df.loc[grouped_cardiovascular_disease_df['Question'].isin(['Current smoking among adults aged >= 18 years', 'Current smokeless cardiovascular_disease use among adults aged >= 18 years'])].loc[grouped_cardiovascular_disease_df['LocationAbbr'] == 'US']\
.loc[grouped_cardiovascular_disease_df['StratificationCategory1'] == 'Overall']

us_overall_df.tail()

# %%
us_overall_df.plot(kind = 'scatter', x='YearEnd', y= 'DataValue', title ='Question' )
# Out:
# <Axes: title={'center': 'Question'}, xlabel='YearEnd', ylabel='DataValue'>
