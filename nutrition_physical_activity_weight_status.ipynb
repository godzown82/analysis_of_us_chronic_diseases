# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt

from cdindicatorFn import check_year_columns, group_sort, question_us_overall, datavalue_type_filter, plot_graph_dict_neutral, change_plot_color

# %%
#reads in the csv file
nutrition_physical_activity_weight_status_df = pd.read_csv('Nutrition, Physical Activity, and Weight Status.csv', low_memory=False)

# %%
#checks to see if columns YearEnd and YearStart have the same value: prints statement and creates new column YearDiffernce if necessary
nutrition_physical_activity_weight_status_df = check_year_columns(nutrition_physical_activity_weight_status_df)
# Out:
# The 'YearStart' and 'YearEnd' columns have the same values in all rows.

# %%
#groups data frames by YearEnd and Question, then sorts the data frame by YearENd least to greatest
nutrition_physical_activity_weight_status_df = group_sort(nutrition_physical_activity_weight_status_df)

# %%
nutrition_physical_activity_weight_status_df['Question'].value_counts()
# Out:
# Question
# Overweight or obesity among adults aged >= 18 years                                                                                                 8966
# Healthy weight among adults aged >= 18 years                                                                                                        8896
# Obesity among adults aged >= 18 years                                                                                                               8883
# No leisure-time physical activity among adults aged >= 18 years                                                                                     8775
# Meeting aerobic physical activity guidelines for substantial health benefits among adults aged >= 18 years                                          3220
# Meeting aerobic physical activity guidelines for additional and more extensive health benefits among adults aged >= 18 years                        3193
# ...

# %%
#creates a dictionary of dataframes that are seperated by question and filtered to US and overall stratification category
# Does not include dataframes that don't include data that can be filtered to US and/or overall
nutrition_physical_activity_weight_status_us_overall = question_us_overall(nutrition_physical_activity_weight_status_df)

# %%
# filters each dataframe in the dictionary to the desired Datavalue type
nutrition_physical_activity_weight_status_us_overall = datavalue_type_filter(nutrition_physical_activity_weight_status_us_overall)

# %%
nutrition_physical_activity_weight_status_df['Question'].value_counts()
# Out:
# Question
# Overweight or obesity among adults aged >= 18 years                                                                                                 8966
# Healthy weight among adults aged >= 18 years                                                                                                        8896
# Obesity among adults aged >= 18 years                                                                                                               8883
# No leisure-time physical activity among adults aged >= 18 years                                                                                     8775
# Meeting aerobic physical activity guidelines for substantial health benefits among adults aged >= 18 years                                          3220
# Meeting aerobic physical activity guidelines for additional and more extensive health benefits among adults aged >= 18 years                        3193
# ...

# %%
#plots each data frame in the dictionary separatley and colors them red, then stores them in a new dictionary graphs
nutrition_physical_activity_weight_status_graphs = plot_graph_dict_neutral(nutrition_physical_activity_weight_status_us_overall)
# Out:
# c:\Users\tyzwh\OneDrive\AI\analysis_of_us_chronic_diseases\cdindicatorFn.py:184: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize = figsize)

# %% [markdown]
# # <center>DATA EXPLORATION<center>
