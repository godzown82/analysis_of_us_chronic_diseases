# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt

from cdindicatorFn import check_year_columns, group_sort, question_us_overall, datavalue_type_filter, plot_graph_dict_neutral, change_plot_color

# %%
#reads in the csv file
diabetes_df = pd.read_csv('Diabetes.csv', low_memory=False)

# %%
#checks to see if columns YearEnd and YearStart have the same value: prints statement and creates new column YearDiffernce if necessary
diabetes_df = check_year_columns(diabetes_df)
# Out:
# The 'YearStart' and 'YearEnd' columns do not have the same values in all rows.

# %%
#groups data frames by YearEnd and Question, then sorts the data frame by YearENd least to greatest
diabetes_df = group_sort(diabetes_df)

# %%
diabetes_df['Question'].value_counts()
# Out:
# Question
# Mortality due to diabetes reported as any listed cause of death                                        11217
# Prevalence of diagnosed diabetes among adults aged >= 18 years                                          7850
# Mortality with diabetic ketoacidosis reported as any listed cause of death                              5829
# Prevalence of depressive disorders among adults aged >= 18 years with diagnosed diabetes                5712
# Influenza vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes        5655
# Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with diagnosed diabetes     5551
# Influenza vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes        5418
# Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with diagnosed diabetes     5374
# Hospitalization with diabetes as a listed diagnosis                                                     3999
# Dilated eye examination among adults aged >= 18 years with diagnosed diabetes                           3450
# Adults with diagnosed diabetes aged >= 18 years who have taken a diabetes self-management course        3445
# Foot examination among adults aged >= 18 years with diagnosed diabetes                                  3443
# Glycosylated hemoglobin measurement among adults aged >= 18 years with diagnosed diabetes               3408
# Prevalence of high blood pressure among adults aged >= 18 years with diagnosed diabetes                 3400
# Prevalence of high cholesterol among adults aged >= 18 years with diagnosed diabetes                    3371
# Amputation of a lower extremity attributable to diabetes                                                3162
# Visits to dentist or dental clinic among adults aged >= 18 years with diagnosed diabetes                2821
# Diabetes prevalence among women aged 18-44 years                                                        1451
# Prevalence of gestational diabetes                                                                        52
# Prevalence of pre-pregnancy diabetes                                                                      23
# Name: count, dtype: int64

# %%
#creates a dictionary of dataframes that are seperated by question and filtered to US and overall stratification category
# Does not include dataframes that don't include data that can be filtered to US and/or overall
diabetes_df_us_overall = question_us_overall(diabetes_df)

# %%
# filters each dataframe in the dictionary to the desired Datavalue type
diabetes_df_us_overall = datavalue_type_filter(diabetes_df_us_overall)

# %%
#plots each data frame in the dictionary separatley and colors them red, then stores them in a new dictionary graphs
diabetes_df_graphs = plot_graph_dict_neutral(diabetes_df_us_overall)

# %% [markdown]
# # <center>DATA EXPLORATION<center>
